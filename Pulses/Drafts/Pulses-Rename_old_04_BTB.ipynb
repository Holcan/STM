# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Rework!

# %% [markdown]
# #### Here we define the corresponding dictionaries containing the information of the pulses

# %%
Rabi={
    'Name': 'Rabi',
    'Amplitude' : 4 ,
    'Start Duration' : 5,
    'End Duration': 5,
    'Start time' : 0,
    'End time': 10,
    'Sweep time': 0
}

# %%
Rabi2={
    'Name': 'Rabi',
    'Amplitude' : 10 ,
    'Start Duration' : 7,
    'End Duration': 8,
    'Start time' : 0,
    'End time': 0,
    'Sweep time': 0
}

# %%
Probe1={
    'Name': 'Probe',
    'Amplitude' : 2 ,
    'Start Duration' : 7,
    'End Duration': 5 ,
    'Start time' : 0,
    'End time': 20,
    'Sweep time': 1
}

# %%
Probe2={
    'Name': 'Probe',
    'Amplitude' : 7 ,
    'Start Duration' : 3,
    'End Duration': 20 ,
    'Start time' : 9,
    'End time': 11,
    'Sweep time': 1
}

# %%
for Pulse in Pulses_List3:
    if Pulse['Sweep time'] == 0:
        print('Not Sweeping', Pulse['Name'])
    else :
        print('Sweeping',Pulse['Name'])
# Out:
# Not Sweeping Rabi
# Sweeping Probe
# Sweeping Probe

# %% [markdown]
# ## Different Pulse schemes given by dictionaries lists, contaning differnt pulses.

# %%
Pulses_List3=[Rabi,Probe1,Probe2];
Pulses_List=[Rabi,Probe1];
Pulses_List2=[Rabi,Probe2];

# %% [markdown]
# ## This function just gives the pulse scheme defined by the parameters of the pulses given in its dictionaries, at their 'Starting time' and with their 'Start Duration'

# %%
def Pul(Pulse,t):
    "single pulse generating function"
    time=np.linspace(-1e-10,t,100)
    pol= np.array([ Pulse['Amplitude']*( Pulse['Start time'] <= x <= Pulse['Start Duration'] + Pulse['Start time']) for x in time ])
    return pol, time

# %%
prueb,trog=Pul(Rabi,50)

# %%
# %matplotlib inline

fig,ax= plt.subplots()



ax.grid(True)
plt.step(trog,prueb)
ax.set_ylabel('V')
ax.set_xlabel('t')
ax.set_title('Pulse Scheme from Pulses_List3, without Sweeping ')

#fig.savefig('Pulse_sweep_t=20',optimize=True,bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Pulse Scheme from Pulses_List3, without Sweeping ')

# %%
def Sweept(PulList,N,n,time):
    """This function calculates an array of the pulse scheme given by the Dictionary List PulList, over the given time interval """
    """ it  uses the number of points N to calculate the time step of the sweeping, and gives the pulse scheme at time step n, n shold be smaller or        equal to N """
    pl1=np.zeros((len(PulList),len(time)))
    for i in range(0,len(PulList)):
        if PulList[i]['Sweep time'] == 0:
            pl1[i]=np.array([ PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  t <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for t in time ])
        if PulList[i]['Sweep time'] == 1:
            dt=(PulList[i]['End time'] - PulList[i]['Start time'])/N
            if n==0:
                pl1[i]=np.array([ PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  t <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for t in time ])
            else:
                pl1[i]=np.array([ PulList[i]['Amplitude'] * (  n*dt <=  t <= PulList[i]['End Duration'] + n*dt) for t in time ])
    y=np.zeros(len(pl1[0]))
    for i in range(0,len(pl1)):
        y += pl1[i]
    return y

# %%
def Pl(PulList,t):
    """Pulse generating function, directly from the specified information given by it's corresponding dictionary, stored in the list PulList,at a time interval given by time"""
    time=np.linspace(-1e-10,t,1000)
    pl=np.zeros((len(PulList),len(time))) 
    for i in range(0,len(PulList)):
        pl[i]=[PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  x <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for x in time ]
    y=np.zeros(len(pl[0]))
    for i in range(0,len(pl)):
        y += pl[i]
    return y

# %% [markdown]
# ## Time interval for now:

# %% [markdown]
# ## Some tests

# %%
a,trog=Pl(Pulses_List3,50)

# %%
b, trog=Pl(Pulses_List,50)

# %%
c, trog=Pl(Pulses_List2,50)

# %%
# %matplotlib inline

fig,ax= plt.subplots()



ax.grid(True)
plt.step(trog,c)
ax.set_ylabel('V')
ax.set_xlabel('t')
ax.set_title('Pulse Scheme from Pulses_List3, without Sweeping ')

#fig.savefig('Pulse_sweep_t=20',optimize=True,bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Pulse Scheme from Pulses_List3, without Sweeping ')

# %% [markdown]
# ### Question: Plotting with plot or step?

# %% [markdown]
# # Now the sweeping function:
# It does not call the Pulse generating function, but it does the same thing, maybe I should rework it a little bit in order to just call that function and have a shorter code

# %%
def Sweept(PulList,N,n,time):
    """This function calculates an array of the pulse scheme given by the Dictionary List PulList, over the given time interval """
    """ it  uses the number of points N to calculate the time step of the sweeping, and gives the pulse scheme at time step n, n shold be smaller or        equal to N """
    pl1=np.zeros((len(PulList),len(time)))
    for i in range(0,len(PulList)):
        if PulList[i]['Sweep time'] == 0:
            pl1[i]=np.array([ PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  t <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for t in time ])
        if PulList[i]['Sweep time'] == 1:
            dt=(PulList[i]['End time'] - PulList[i]['Start time'])/N
            if n==0:
                pl1[i]=np.array([ PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  t <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for t in time ])
            else:
                pl1[i]=np.array([ PulList[i]['Amplitude'] * (  n*dt <=  t <= PulList[i]['End Duration'] + n*dt) for t in time ])
    y=np.zeros(len(pl1[0]))
    for i in range(0,len(pl1)):
        y += pl1[i]
    return y

# %%
khe=Sweept(Pulses_List,10,10,trog); #different time step of the sweeping given by n, it should be n <= N in order to finish at 'End time'
# %matplotlib inline

fig,ax= plt.subplots()



ax.grid(True)
plt.plot(trog,khe)
ax.set_ylabel('V')
ax.set_xlabel('t')
ax.set_title(' Pulse Scheme from Pulses_List, at sweeping time n=50 ')

#fig.savefig('Pulse_sweep_t=20',optimize=True,bbox_inches='tight')
# Out:
# Text(0.5, 1.0, ' Pulse Scheme from Pulses_List, at sweeping time n=50 ')

# %% [markdown]
# ## to do: Implement the sweeping with respect to the duration:

# %%
def Sweept(PulList,N,n,t):
    """This function calculates an array of the pulse scheme given by the Dictionary List PulList, over the given time interval """
    """ it  uses the number of points N to calculate the time step of the sweeping, and gives the pulse scheme at time step n, n shold be smaller or        equal to N """
    time=np.linspace(-1e-10,t,1000)
    pl1=np.zeros((len(PulList),len(time)))
    for i in range(0,len(PulList)):
        if PulList[i]['Sweep time'] == 0:
            pl1[i]=np.array([ PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  x <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for x in time ])
        if PulList[i]['Sweep time'] == 1:
            dt=(PulList[i]['End time'] - PulList[i]['Start time'])/N
            if n==0:
                pl1[i]=np.array([ PulList[i]['Amplitude'] * (  PulList[i]['Start time'] <=  x <= PulList[i]['Start Duration'] + PulList[i]['Start time']) for x in time ])
            else:
                pl1[i]=np.array([ PulList[i]['Amplitude'] * (  n*dt <=  x <= PulList[i]['End Duration'] + n*dt) for x in time ])
    y=np.zeros(len(pl1[0]))
    for i in range(0,len(pl1)):
        y += pl1[i]
    return y
