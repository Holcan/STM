# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
header_list = ["Frequency [Hz]","S11 Magnitude[db]","S11 Phase[degrees]","S21 Magnitude[db]","S21 Phase[degrees]", "S12 Magnitude[db]", "S12 Phase[degrees]", "S22 Magnitude[db]", "S22 Phase[degrees]"]

# %%
kabel1 = pd.read_csv("Rotes Kabel 1 text.txt",names = header_list ,delimiter =  " ")

# %%
kabel1
# Out:
#        Frequency [Hz]  S11 Magnitude[db]  S11 Phase[degrees]  \
# 0          1000000000          -34.86530           115.35880
# 1          1003062500          -34.83219            73.94574
# 2          1006125000          -36.37335            49.78261
# 3          1009187500          -39.52796            55.68839
# 4          1012250000          -36.36697            87.34699
# ...               ...                ...                 ...
# 15996     49987750000          -13.56820           -72.45668
# 15997     49990812500          -13.47726           -71.66410
# 15998     49993875000          -13.29188           -71.53676
# 15999     49996937500          -13.08266           -72.31107
# 16000     50000000000          -12.88069           -73.93693
#
#        S21 Magnitude[db]  S21 Phase[degrees]  S12 Magnitude[db]  \
# 0              -1.991340           -88.51910          -2.255466
# 1              -1.990496          -108.68890          -2.256176
# ...

# %% [markdown]
# S11 and s22 should be symmetric, as well as s12,s21 plot them

# %%
kabel1["Frequency [Hz]"][2500:]
# Out:
# 2500      8656250000
# 2501      8659312500
# 2502      8662375000
# 2503      8665437500
# 2504      8668500000
#             ...
# 15996    49987750000
# 15997    49990812500
# 15998    49993875000
# 15999    49996937500
# 16000    50000000000
# Name: Frequency [Hz], Length: 13501, dtype: int64

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(kabel1["Frequency [Hz]"][0:1000]/1e9,kabel1["S11 Magnitude[db]"][0:1000],label = "S11 parameter", color="red")
plt.plot(kabel1["Frequency [Hz]"][0:1000]/1e9,kabel1["S22 Magnitude[db]"][0:1000],label = "S22 parameter", color="blue")

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=0)
plt.show()

fig.savefig(r'S Parameters, red cable till 4GHz.jpeg',bbox_inches='tight')

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(kabel1["Frequency [Hz]"][1000:2400]/1e9,kabel1["S11 Magnitude[db]"][1000:2400],label = "S11 parameter", color="red")
plt.plot(kabel1["Frequency [Hz]"][1000:2400]/1e9,kabel1["S22 Magnitude[db]"][1000:2400],label = "S22 parameter", color="blue")

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S parameters')
ax.legend(loc=0)
plt.show()

fig.savefig(r'S Parameters, red cable 4GHz-8GHz.jpeg',bbox_inches='tight')

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(kabel1["Frequency [Hz]"][0:1000]/1e9,kabel1["S12 Magnitude[db]"][0:1000],label = "S12 parameter", color="green")
plt.plot(kabel1["Frequency [Hz]"][0:1000]/1e9,kabel1["S21 Magnitude[db]"][0:1000],label = "S21 parameter", color="orange")

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=0)
plt.show()

fig.savefig(r'Transmision S Parameters, red cable till 4GHz.jpeg',bbox_inches='tight')

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(kabel1["Frequency [Hz]"][1000:2400]/1e9,kabel1["S12 Magnitude[db]"][1000:2400],label = "S12 parameter", color="green")
plt.plot(kabel1["Frequency [Hz]"][1000:2400]/1e9,kabel1["S21 Magnitude[db]"][1000:2400],label = "S21 parameter", color="orange")

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=0)
plt.show()

fig.savefig(r'Transmision  S Parameters, red cable 4GHz-8GHz.jpeg',bbox_inches='tight')

# %%
usecols=['freq[Hz]','re:S11','re:S21','re:S12','re:S22']

# %%
Cable_rojo_D  =  pd.read_csv("uhoh text.csv")

# %% [markdown]
# freq[Hz]                re:S11                  im:S11                  re:S21                  im:S21                  re:S12                  im:S12                  re:S22                  im:S22

# %%
Cable_rojo_D
# Out:
#             Freq     reS11     imS11     reS21     imS21      re12      im12  \
# 0       10000000 -0.015271  0.013415  1.016806 -0.135418  0.960149 -0.148188
# 1       96980000 -0.010908 -0.009340  0.036526 -0.988428  0.039296 -0.984084
# 2      183960000 -0.003847  0.006719 -0.954793 -0.234939 -0.950910 -0.233751
# 3      270940000 -0.004492 -0.007170 -0.422995  0.882361 -0.420867  0.878979
# 4      357920000 -0.012467  0.010426  0.773612  0.591760  0.770821  0.589336
# ..           ...       ...       ...       ...       ...       ...       ...
# 496  43152080000  0.239243 -0.508445 -0.370824 -0.109025 -0.362942 -0.102092
# 497  43239060000 -0.038365 -0.236087 -0.251432  0.399286 -0.242126  0.393545
# 498  43326040000  0.238005 -0.457612  0.317293  0.217703  0.312701  0.207092
# 499  43413020000 -0.099513 -0.467104  0.344944 -0.196106  0.329254 -0.200399
# 500  43500000000  0.174739 -0.189920 -0.209698 -0.379399 -0.212333 -0.362998
#
#          re22      im22
# ...

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(Cable_rojo_D['Freq'][250:]/1e9,Cable_rojo_D['reS11'][250:],label = 'S11 Parameter', color = 'red')
plt.plot(Cable_rojo_D['Freq'][250:]/1e9,Cable_rojo_D['re22'][250:],label = 'S22 Parameter', color = 'blue')

ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=0)
plt.show()

#fig.savefig(r'S Parameters, red cable till 4GHz.jpeg',bbox_inches='tight')

# %%
Cable_rojo_D['freq[Hz]']
# Out:
# 0     -0.015271
# 1     -0.010908
# 2     -0.003847
# 3     -0.004492
# 4     -0.012467
#          ...
# 496    0.239243
# 497   -0.038365
# 498    0.238005
# 499   -0.099513
# 500    0.174739
# Name: freq[Hz], Length: 501, dtype: float64

# %% [markdown]
# !Agilent Technologies,E8364B,US41440127,A.06.04.32
# !Agilent E8364B: A.06.04.32
# !Date: Tuesday, August 11, 2020 14:30:28
# !Correction: S11(Off) S21(Off) S12(Off) S22(Off)
# !S2P File: Measurements: S11, S21, S12, S22:
# Hz S dB R 50

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(Cable_rojo_D['Freq'][:100]/1e9,Cable_rojo_D['reS11'][:100],label = 'S11 Parameter', color = 'red')
plt.plot(Cable_rojo_D['Freq'][:100]/1e9,Cable_rojo_D['re22'][:100],label = 'S22 Parameter', color = 'blue')

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=0)
plt.show()

fig.savefig(r'S Parameters, red cable damaged.jpeg',bbox_inches='tight')

# %%
fig,  ax = plt.subplots()

ax.grid(True)

#plt.plot(Cable_rojo_D['Freq'][:100]/1e9,Cable_rojo_D['re12'][:100],label = 'S12 Parameter', color = 'green')
plt.plot(Cable_rojo_D['Freq'][:100]/1e9,Cable_rojo_D['reS21'][:100],label = 'S21 Parameter', color = 'orange')

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=1)
plt.show()

#fig.savefig(r'S Parameters transmision S21, red cable damaged.jpeg',bbox_inches='tight')

# %% [markdown]
# # Before Damage

# %%
Cable_rojo_antes  =  pd.read_csv("red cabel text.csv")

# %%
Cable_rojo_antes
# Out:
#             Freq     res11     ims11     res21      im21     res12      im12  \
# 0       10000000 -0.007073  0.015577  1.035228 -0.105134  0.975007 -0.186266
# 1       96980000 -0.013549 -0.011260  0.036471 -0.984534  0.036451 -0.985909
# 2      183960000 -0.002968  0.011718 -0.950398 -0.232613 -0.952023 -0.232513
# 3      270940000 -0.002391 -0.012927 -0.419288  0.878451 -0.419022  0.880130
# 4      357920000 -0.018054  0.014748  0.770467  0.586610  0.771635  0.586861
# ..           ...       ...       ...       ...       ...       ...       ...
# 496  43152080000  0.121789 -0.324330 -0.446025 -0.380314 -0.445571 -0.359521
# 497  43239060000 -0.074536 -0.230465 -0.499127  0.346681 -0.483049  0.353224
# 498  43326040000  0.069635 -0.295714  0.272964  0.519405  0.282874  0.504620
# 499  43413020000 -0.102246 -0.357038  0.556627 -0.106448  0.539932 -0.130078
# 500  43500000000 -0.031890 -0.162063 -0.024565 -0.599732 -0.048805 -0.585430
#
#         res22      im22
# ...

# %%
fig,  ax = plt.subplots()

ax.grid(True)

plt.plot(Cable_rojo_antes['Freq'][:100]/1e9,Cable_rojo_antes['res11'][:100],label = 'S11 Parameter', color = 'red')
plt.plot(Cable_rojo_antes['Freq'][:100]/1e9,Cable_rojo_antes['res22'][:100],label = 'S22 Parameter', color = 'blue')

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=0)
plt.show()

fig.savefig(r'S Parameters reflection, red cable till before damage.jpeg',bbox_inches='tight')

# %%
fig,  ax = plt.subplots()

ax.grid(True)

#plt.plot(Cable_rojo_antes['Freq'][:100]/1e9,Cable_rojo_antes['res12'][:100],label = 'S12 Parameter', color = 'green')
plt.plot(Cable_rojo_antes['Freq'][:100]/1e9,Cable_rojo_antes['res21'][:100],label = 'S21 Parameter', color = 'orange')

ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('dB')
ax.set_title('Red Cable S Parameters Magnitude')
ax.legend(loc=1)
plt.show()

#fig.savefig(r'S Parameters Transmision 21, red cable before.jpeg',bbox_inches='tight')
