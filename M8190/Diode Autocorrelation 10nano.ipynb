# %%
# %matplotlib widget

# %%
import numpy as np
from numpy import loadtxt
import pandas as pd
import time
import matplotlib
import matplotlib.pyplot as plt
import pyvisa as visa
from matplotlib import animation
from time import sleep
from matplotlib.animation import FuncAnimation
#Importing the functions from the module and the pulses dictionaries
from Sweeping import *
from Dictionaries import *
from PulseFiles import *
from Instrument import *
import pyqtgraph as pg 
import nidaqmx
import pickle

# %% [markdown]
# # Instrument settings and CSV file path Dictionary

# %%
AWG_Settings= {
    'Visa Resource Name': 'TCPIP0::ibn3-036.ibn-net.kfa-juelich.de::hislip0::INSTR',
    'Voltage Amplitude':700,
    'Clock Sample Frecuency':6000000000,
    'Output_Channel': 1,
    'Mode': 'STS',
    'Trigger In Threshold' : 1,
    'Output Rout': 'DAC', #DAC output rout only has the BNC outputs: Direct Out and (Averaged) Direct Out
    'Data Directory': r'D:\Alejandro\Pulses\diode measurements\Pulse Scheme CSV\Measurements\10nano'
}

# %%
M8190A = VisaR(AWG_Settings,60000)

# %%
M8190A.query('SYST:ERR?')
# Out:
# '0,"No error"'

# %%
Initialization(M8190A,AWG_Settings)
# Out:
# Instruments Sampling Frecuency set to 6.00000000000000E+09Hz
# Instruments Direct Out DAC Output route Voltage set to 7.00000000000000E-01Volts
# AWG_Settings_Dict set to TRIGGERED Mode
# Trigger In threshold value set to 1.00000000000000E+00V

# %%
M8190A.write('SEQ:DEL:ALL')
# Out:
# 12

# %% [markdown]
# # Pulses Dictionaries

# %%
Pump = {
    'Name':'Pump',
    'Amplitude':40,
    'Start time':20,
    'End time':2e-10,
    'Start Duration':10,
    'End Duration':60,
    'Sweep time':0,
    'Sweep Duration':0
}

# %%
ProbeA = {
    'Name':'ProbeA',
    'Amplitude':25,
    'Start time':0,
    'End time':40,
    'Start Duration':10,
    'End Duration':60,
    'Sweep time':1,
    'Sweep Duration':0
}

# %%
ProbeB = {
    'Name':'ProbeB',
    'Amplitude':0,
    'Start time':0,
    'End time':12,
    'Start Duration':1,
    'End Duration':6,
    'Sweep time':0,
    'Sweep Duration':0
}

# %% [markdown]
# # Pulse Schemes Dictionaries and measurement path file

# %%
PulseScheme_A =  {
    'Name' : 'PulseScheme_A',
    'Pulse Scheme': [Pump,ProbeA],
    'Number of repetitions': 50000,
    'Measurement file Path': r'D:\Alejandro\Pulses\diode measurements\TList\10nano'
}

# %%
PulseScheme_B  = {
    'Name' : 'PulseScheme_B',
    'Pulse Scheme': [ProbeB,ProbeB],
    'Number of repetitions': 1,
    'Measurement file Path': r'D:\Alejandro\Pulses\diode measurements\TList\10nano'
}

# %%
location = PulseScheme_A['Measurement file Path']

# %% [markdown]
# # Number of Samples given the AWG Sampling rate and the Reference Signal Frequency
# ## Sr = 6Ghz for 5 ms

# %%
sam = int(3e9*5e-3)

#sam /480

M8190A.write('FREQ:RAST 3000000000')
# Out:
# 21

# %%
sam/48
# Out:
# 312500.0

# %%
pul2 = Sweep(PulseScheme_B['Pulse Scheme'],10,0,5,sam)

# %%
# %matplotlib inline

# %%
# %matplotlib widget

# %%
location = PulseScheme_A['Measurement file Path']

# %%
sam = int(6e9*5e-3)
step = 30
pul1 = Sweep_teil(PulseScheme_A,30,step,5000000,sam)


#Plot
fig,ax= plt.subplots()
ax.grid(True)

plt.plot(pul1[1],pul1[0],label= '{b} samples'.format(b = sam),color='orange')

ax.set_ylabel('V  [mV]')
ax.set_xlabel(r't [ns]')
ax.set_title('Cycle A at step {a}, {r} Pump-probe repetitions'.format(a = step, r = PulseScheme_A['Number of repetitions'])) #Voltage Offset = 3mV, Marker Ampl = 50mV 
#ax.legend(loc=0)
#plt.legend(bbox_to_anchor=(2.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
#fig.savefig('Cycle A, Probe width 10nanos.jpeg',bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

# %%
step = 30

pul1 = Sweep_teil(PulseScheme_A,30,step,5000000,sam)

fig,ax= plt.subplots()
ax.grid(True)

#plt.plot(timeMs,dataMs[1]*1000,label= 'Marker Channel {chan}'.format(chan=DAQ_Settings1['Analog Channel Input Marker']),color='purple')
plt.plot(pul1[1],pul1[0],label= '{b} samples'.format(b = sam),color='orange')

ax.set_ylabel('V  [mV]')
ax.set_xlabel('t  [ns]')
ax.set_title('Cycle A at step {a}, {rep} repetitions'.format(a = step,rep = PulseScheme_A['Number of repetitions'])) #Voltage Offset = 3mV, Marker Ampl = 50mV 
#ax.legend(loc=0)
#plt.legend(bbox_to_anchor=(2.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
#fig.savefig(r'{loc}\Cycle A {reps} reps.jpeg'.format(loc =location, reps = PulseScheme_A['Number of repetitions']),bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
step = 30

#pul1 = Sweep_teil(PulseScheme_AutocorrelationA,30,step,5000,sam)


fig,ax= plt.subplots(2)


ax[0].grid(True)
ax[1].grid(True)
fig.suptitle('Pulses Loaded into the AWG')


ax[0].plot(pul1[1],pul1[0],label= 'Pulse A',color='blue')
ax[1].plot(pul2[1],pul2[0],label= 'Pulse B',color='red')
ax[0].set_ylabel('V  [mV]')
ax[0].set_xlabel(r't  [$\mu$s]')
ax[1].set_ylabel('V  [mV]')
ax[1].set_xlabel(r't  [ms]')

#ax.set_title('Pulses Loaded into the AWG')

fig.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

#fig.savefig('Pulse_scheme_15ms_7500000',optimize=True,bbox_inches='tight')

# %% [markdown]
# # Dummy File Loading

# %%
Dummy_File(M8190A)
# Out:
# Dummy File Loaded and playing
# Dummy File stopped and erased from AWGs memmory

# %%
M8190A.write('SEQ:DEL:ALL')
# Out:
# 12

# %%
sweeping_run_a = Sweeping_Single_List_File_teil(PulseScheme_A,30,5000000,sam,0,30,AWG_Settings,'A')[0]
#sweeping_runb = Sweeping_Single_List_File_teil(PulseScheme_B,30,5000,sam,0,30,AWG_Settings8,'B')[0]

# %%
sweeping_runb = Sweeping_Single_List_File_teil(PulseScheme_B,30,5000000,sam,0,30,AWG_Settings,'B')[0]

# %%
#exporting pickle 

pickle.dump(sweeping_run_a, open(r"{dict}\cycleA_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "wb"))  # save it into a file named sweepingA.p
pickle.dump(sweeping_runb, open(r"{dict}\cycleB_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "wb"))  # save it into a file named sweepingB.p
# Out:
# <ipython-input-51-09d117081655>:3: ResourceWarning: unclosed file <_io.BufferedWriter name='D:\\Alejandro\\Pulses\\diode measurements\\TList\\10nano\\cycleA_31steps_5ms_10nano_probe.p'>
#   pickle.dump(sweeping_run_a, open(r"{dict}\cycleA_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "wb"))  # save it into a file named sweepingA.p
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# <ipython-input-51-09d117081655>:4: ResourceWarning: unclosed file <_io.BufferedWriter name='D:\\Alejandro\\Pulses\\diode measurements\\TList\\10nano\\cycleB_31steps_5ms_10nano_probe.p'>
#   pickle.dump(sweeping_runb, open(r"{dict}\cycleB_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "wb"))  # save it into a file named sweepingB.p
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
#importing pickle

sweeping_run_a = pickle.load(open(r"{dict}\cycleA_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "rb"))
sweeping_runb = pickle.load(open(r"{dict}\cycleB_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "wb"))
# Out:
# <ipython-input-11-810f41751397>:3: ResourceWarning: unclosed file <_io.BufferedReader name='D:\\Alejandro\\Pulses\\diode measurements\\TList\\10nano\\cycleA_31steps_5ms_10nano_probe.p'>
#   sweeping_run_a = pickle.load(open(r"{dict}\cycleA_31steps_5ms_10nano_probe.p".format(dict = PulseScheme_A['Measurement file Path']), "rb"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# <ipython-input-11-810f41751397>:4: ResourceWarning: unclosed file <_io.BufferedReader name='sweepingB_30steps_5ms_10micro_probe.p'>
#   sweeping_runb = pickle.load(open("sweepingB_30steps_5ms_10micro_probe.p", "rb"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
sweeping_run_a
# Out:
# {'Pulse File Location, at step 0': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_0.csv',
#  'Pulse File Location, at step 1': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_1.csv',
#  'Pulse File Location, at step 2': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_2.csv',
#  'Pulse File Location, at step 3': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_3.csv',
#  'Pulse File Location, at step 4': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_4.csv',
#  'Pulse File Location, at step 5': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_5.csv',
#  'Pulse File Location, at step 6': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_6.csv',
#  'Pulse File Location, at step 7': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_7.csv',
#  'Pulse File Location, at step 8': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_8.csv',
#  'Pulse File Location, at step 9': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_9.csv',
#  'Pulse File Location, at step 10': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_10.csv',
#  'Pulse File Location, at step 11': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_11.csv',
#  'Pulse File Location, at step 12': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_12.csv',
#  'Pulse File Location, at step 13': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_13.csv',
#  'Pulse File Location, at step 14': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_14.csv',
#  'Pulse File Location, at step 15': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_15.csv',
#  'Pulse File Location, at step 16': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_16.csv',
#  'Pulse File Location, at step 17': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_17.csv',
#  'Pulse File Location, at step 18': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_18.csv',
#  'Pulse File Location, at step 19': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_19.csv',
#  'Pulse File Location, at step 20': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_20.csv',
#  'Pulse File Location, at step 21': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_21.csv',
#  'Pulse File Location, at step 22': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_22.csv',
#  'Pulse File Location, at step 23': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_23.csv',
#  'Pulse File Location, at step 24': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_24.csv',
#  'Pulse File Location, at step 25': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_25.csv',
#  'Pulse File Location, at step 26': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_26.csv',
#  'Pulse File Location, at step 27': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_27.csv',
#  'Pulse File Location, at step 28': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_28.csv',
#  'Pulse File Location, at step 29': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_29.csv',
#  'Pulse File Location, at step 30': 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\Measurements\\10nano\\SegmentA_15000000_30.csv'}

# %%
location
# Out:
# 'D:\\Alejandro\\Pulses\\diode measurements\\TList\\10nano'

# %%
M8190A.write('SEQ:DEL:ALL')
# Out:
# 12

# %%
Lock_In_Settings = {
'Time Constant' : '10ms',
'Sensitivity' : '100 microVolts',
'Reserve' : 'Normal',
'db' : 24,
'Modulation': '1000Hz'
}

# %%
playing_time = 10 #in seconds

Diode_Signal, averaged_data = Measurement_Autocorrelation_voltage(M8190A,DAQ_Settings1,1000, playing_time ,sweeping_run_a,sweeping_runb,PulseScheme_A['Measurement file Path'],Lock_In_Settings)
# Out:
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 0
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 1
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 2
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 3
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 4
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 5
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 6
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 7
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 8
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 9
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 10
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 11
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 12
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 13
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 14
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 15
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 16
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 17
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 18
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 19
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 20
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 21
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 22
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 23
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 24
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 25
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 26
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 27
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 28
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 29
# Sequence loaded with the following segment data "1,1,0,1,0,14999999,2,1,0,1,0,14999999" and the advancement method is COND
# Triggering Pulse Stoped
# Data acquired for Step 30

# %%
# %matplotlib inline

# %%
fig,ax= plt.subplots()
ax.grid(True)
for i in range(0,len(Diode_Signal)):
    plt.plot(Diode_Signal[i][1],Diode_Signal[i][0],label= 'Step {st}'.format(st = i ))

ax.set_ylabel(r'V  [V]')
ax.set_xlabel('t  [s]')
ax.set_title(r' Diode Signal at Different Steps,  {b} Samples, 1ms probe duration'.format(b = len(Diode_Signal[0][1]) ))
#ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#ax.legend(loc=0)
plt.show()
fig.savefig(r'{loc}\Diode Signal time cstant = {a}, sensitivity {b},{c} daqseconds, 5ms scheme, probe duration 10ns,31 steps, no legend,3Ghz .jpeg'.format(loc = PulseScheme_A['Measurement file Path'],a = Lock_In_Settings['Time Constant'], b = Lock_In_Settings['Sensitivity'], c = playing_time),bbox_inches='tight')

# %%
time_delay = np.linspace(-20,20,31)

# %%
#change this to V regime
fig,axes = plt.subplots()

axes.grid(True)

plt.plot(time_delay,averaged_data,label=r'1 ms Probe Width ',color='blue')
#plt.plot(tm,pul,label = '{a} samples'.format(a = len(pul)))

axes.set_xlabel(r'time delay [ms]')
axes.set_ylabel(r'Diode Signal [V]')
axes.set_title('Auto-Correlation 31 steps ')

axes.legend(loc = 0)
plt.show()

fig.savefig(r'{loc}\Autocorrelation function 31 steps probes 5ms length tc = {a}, sens {b} centered {c}s DAQ 3Ghz.jpeg'.format(loc = PulseScheme_A['Measurement file Path'],a = Lock_In_Settings['Time Constant'], b = Lock_In_Settings['Sensitivity'], c = playing_time ))

# %%
fig,ax= plt.subplots()
ax.grid(True)
for i in range(0,len(Diode_Signal)):
    plt.plot(Diode_Signal[i][1],Diode_Signal[i][0],label= 'Step {st}'.format(st = i ))

ax.set_ylabel(r'V  [V]')
ax.set_xlabel('t  [s]')
ax.set_title(r' Diode Signal Measured by DAQ, 31 steps with {b} samples, 10ns probe duration'.format(b = len(Diode_Signal[0][1]) ))
#ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#ax.legend(loc=0)
plt.show()
fig.savefig(r'{loc}\Diode Signal time cstant = 30ms sensitivity 100microV,{f}s daqtime, 5ms scheme, probe duration 10nano,31 steps,60kreps .jpeg'.format(loc = location, f = DAQ_time),bbox_inches='tight')

# %%
location
# Out:
# 'D:\\Alejandro\\Pulses\\diode measurements\\TList\\10nano'

# %%
for i in range(0,len(Diode_Signal)):
    np.savetxt(r'{loc}\diode_signal_step{stp}_{f}sdaqtime_5ms_30tc_100microV_60kreps.csv'.format(loc = location ,stp = i, f = DAQ_time), Diode_Signal[i][0], delimiter=',') 

chopped_measurement_data = np.zeros((len(Diode_Signal)),  dtype=object)
for i in range(0,len(Diode_Signal)):
    chopped_measurement_data[i] = Diode_Signal[i][0][2500:] 

avr = np.array([np.average(i) for i in chopped_measurement_data])
np.savetxt(r'{loc}\averaged signal_31steps_{f}sdaqtime_5ms_30tc_100microV_60kreps.csv'.format(loc =location, f = DAQ_time),avr,delimiter=',')

# %%
#np.savetxt(r'averaged signal_30steps_10nano_20sdaqtime_2000rep.csv',avr,delimiter=',')

# %%
time_delay = np.linspace(-20,20,31)

# %%
#change this to V regime
fig,axes = plt.subplots()

axes.grid(True)

plt.plot(time_delay,avr,label=r'10ns Probe Width ',color='black')

axes.set_xlabel(r'time delay [ns]')
axes.set_ylabel(r'Diode Signal [V]')
axes.set_title('Auto-Correlation 31 steps ')

axes.legend(loc = 0)
plt.show()

fig.savefig(r'{loc}\Autocorrelation function 31 steps 10nano probe, tc = 30ms,sens =100microV,{f}sdaqtime, 60kreps.jpeg'.format(loc = location, f = DAQ_time),bbox_inches='tight')

# %% [markdown]
# # Load numpy array from csv file

# %%
# load array
avrg_1point5 = loadtxt('averaged signal_30steps_onepoint5.csv',delimiter= ",")
avrg_point1 = loadtxt('averaged signal_30steps_point1.csv',delimiter = ',')
avrg_1 = loadtxt('averaged signal_30steps_35seconds.csv', delimiter=',')
avrg_pointfive = loadtxt('averaged signal_30steps_35seconds_pointfive.csv', delimiter=',')
avrg_10micro = loadtxt('averaged signal_30steps_10micro.csv', delimiter= ',')
# print the array

# %%
fig,axes = plt.subplots()

axes.grid(True)
#plt.plot(time_delay,avrg_1,label='Probe width 1',color='black')
plt.plot(time_delay,avrg_10micro,label=r'10 $\mu$s Probe Width ',color='green')
plt.plot(time_delay,avrg_1,label='Probe width 1 ms',color='blue')
#plt.plot(time_delay,avrg_pointfive,label = 'Probe width 0.5', color = 'purple')
#plt.plot(time_delay,avrg_point1,label='Probe width 0.1',color='red')


axes.set_xlabel('time delay [ms]')
axes.set_ylabel(r'Diode Signal [V]')
axes.set_title('Auto-Correlation Signal, 30 Steps ')

axes.legend(loc = 0)
plt.show()

#fig.savefig('Autocorrelation 1ms Width scheme.jpeg',bbox_inches='tight')

# %%
fig,axes = plt.subplots()

axes.grid(True)
plt.plot(time_delay,avr,label='Probe width 2',color='black')
plt.plot(time_delay,avrg_1point5,label='Probe width 1.5',color='green')
plt.plot(time_delay,avrg_1,label='Probe width 1',color='blue')
plt.plot(time_delay,avrg_pointfive,label = 'Probe width 0.5', color = 'purple')
plt.plot(time_delay,avrg_point1,label='Probe width 0.1',color='red')


axes.set_xlabel('time delay [ms]')
axes.set_ylabel(r'Diode Signal [V]')
axes.set_title('Auto-Correlation Signal, 30 Steps ')

axes.legend(loc = 0)
plt.show()

#fig.savefig('Autocorrelation 2 width.jpeg',bbox_inches='tight')

# %%
do 1 more 1.5 probe plot

# %%
 np.where(haber[0][1] > 3 )
# Out:
# (array([ 3000,  3001,  3002, ..., 34997, 34998, 34999], dtype=int64),)

# %%
# %matplotlib inline

# %%
import glob
print(glob.glob('D:\Alejandro\Pulses\diode measurements\Pulse Scheme CSV\AutoCorrelation, ms regime, 0,1 probe duration\*csv'))
#print(glob.glob("/home/adam/*"))
# Out:
# ['D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_0.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_1.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_10.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_11.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_12.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_13.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_14.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_15.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_16.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_17.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_18.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_19.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_2.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_20.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_21.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_22.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_23.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_24.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_25.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_26.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_27.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_28.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_29.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_3.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_30.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_4.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_5.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_6.csv', 'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_7.csv', 'D:\\Alejandro\\Pulses\\diode meas ...

# %%
a = glob.glob('D:\Alejandro\Pulses\diode measurements\Pulse Scheme CSV\AutoCorrelation, ms regime, 0,1 probe duration\*csv')

# %%
a
# Out:
# ['D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_0.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_1.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_10.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_11.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_12.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_13.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_14.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_15.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_16.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_17.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_18.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_19.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_2.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_20.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_21.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_22.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_23.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_24.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_25.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_26.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_27.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_28.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_29.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_3.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_30.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_4.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_5.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_6.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_7.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_8.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentA_30000000_9.csv',
#  'D:\\Alejandro\\Pulses\\diode measurements\\Pulse Scheme CSV\\AutoCorrelation, ms regime, 0,1 probe duration\\SegmentB_30000000_0.csv']

# %% [markdown]
# # Tiling

# %%
Pump = {
    'Name':'Pump',
    'Amplitude':40,
    'Start time':2e-10,
    'End time':2e-10,
    'Start Duration':2,
    'End Duration':6,
    'Sweep time':0,
    'Sweep Duration':0
}

# %%
ProbeAutoA = {
    'Name':'ProbeAutoA',
    'Amplitude':25,
    'Start time':0,
    'End time':4,
    'Start Duration':1,
    'End Duration':6,
    'Sweep time':1,
    'Sweep Duration':0
}

# %%
ProbeAutoB = {
    'Name':'ProbeAutoB',
    'Amplitude':0,
    'Start time':0,
    'End time':12,
    'Start Duration':1,
    'End Duration':6,
    'Sweep time':0,
    'Sweep Duration':0
}

# %%
ProbeAutoC = {
    'Name':'ProbeAutoB',
    'Amplitude':35,
    'Start time':3,
    'End time':12,
    'Start Duration':3,
    'End Duration':6,
    'Sweep time':0,
    'Sweep Duration':0
}

# %%
AutoCorSchemeA = [Pump, ProbeAutoA]
AutoCorSchemeB = [ProbeAutoB, ProbeAutoB]
AutoCorSchemeC = [Pump,ProbeAutoC]
#step = 0

# %%
ProbeAutoC = {
    'Name':'ProbeAutoB',
    'Number of Repetitions': 1,
    'Amplitude':35,
    'Start time':6,
    'End time':12,
    'Start Duration':3,
    'End Duration':6,
    'Sweep time':0,
    'Sweep Duration':0
}

# %%
PulseSchemetest =  {
    'Name' : 'PulseSchemetest',
    'Pulse Scheme': [Pump,ProbeAutoC],
    'Number of repetitions': 4,
}

# %%
def Sweepteil(PulList,P,p,t,N):
    
    """Function that perfoms or not a Sweep, depending on the Sweep dictionary keys, for the Pulse Scheme PulList.
    
    This function is a generalization of the sweep0(Pulse,P,p,t).
    It calls it and maps it over every Pulse in the list of pulses PulList.
    If two pulses overlap, their amplitude is added up.
    P gives the number of sample points for the overal pulse scheme, not to be confused with dt, the sweeping time step given by P
    The pulse sequence is generated in the order that the pulses have within the PulseList.
    """
    
    #time interval
    time = np.linspace(0,t,N)
    
    #Each pulse will be an array, and an entry of a bigger array (we have an array of arrays)
    pularray = np.array([sweep0(Pulse,P,p,t,N) for Pulse in PulList['Pulse Scheme']])
        
    #the final pulse scheme will be the overlap of each individual pulse, given by the sum of their arrays    
    pulscheme0 = np.sum(pularray,0)

    #we divide the pulse scheme in order to play it several times
    teil = int(pulscheme0.size/PulList['Number of repetitions'])
    pulscheme = np.tile(pulscheme0[:teil],PulList['Number of repetitions'])
    
        
    return pulscheme, time

# %%
def Sweept(PulList,P,p,t,N,rep):
    
    """Function that perfoms or not a Sweep, depending on the Sweep dictionary keys, for the Pulse Scheme PulList.
    
    This function is a generalization of the sweep0(Pulse,P,p,t).
    It calls it and maps it over every Pulse in the list of pulses PulList.
    If two pulses overlap, their amplitude is added up.
    P gives the number of sample points for the overal pulse scheme, not to be confused with dt, the sweeping time step given by P
    The pulse sequence is generated in the order that the pulses have within the PulseList.
    """
    
    #time interval
    time = np.linspace(0,t,N)
    
    #Each pulse will be an array, and an entry of a bigger array (we have an array of arrays)
    pularray = np.array([sweep0(Pulse,P,p,t,N) for Pulse in PulList['Pulse Scheme']])
        
    #the final pulse scheme will be the overlap of each individual pulse, given by the sum of their arrays    
    pulscheme0 = np.sum(pularray,0)

    #we divide the pulse scheme in order to play it several times
    teil = int(pulscheme0.size/rep)
    pulscheme = np.tile(pulscheme0[:teil],rep)
    
        
    return pulscheme, time

# %%
pul = Sweept(PulseSchemetest,10,0,100,7500000,10)

# %%
n = 10
pul = Sweept(PulseSchemetest,10,0,100,7500000,n)
#teil = int(pul[0].size/n)
#huh = np.tile(pul[0][:teil],n)

fig,axes = plt.subplots()
axes.grid(True)

plt.plot(pul[1],pul[0],label = 'Step 0' )
#plt.plot(tim2,pul1,label = 'part2' )

axes.set_xlabel('t [ms]')
axes.set_ylabel('v[mV]')
axes.set_title('Auto-Correlation Cycle A repeated {a} times'.format( a = n ))

#axes.legend(loc = 0)
plt.show()

#fig.savefig('{a} pulses per segment.png'.format( a = n))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,axes = plt.subplots()

axes.grid(True)

plt.plot(pul[1],pul[0],label = '{a} samples'.format(a = len(pul[0])))
#plt.plot(tm,pul,label = '{a} samples'.format(a = len(pul)))

axes.set_xlabel('t [ms]')
axes.set_ylabel('v[mV]')
axes.set_title('Auto-Correlation Pulse Scheme at step 0')

axes.legend(loc = 0)
plt.show()

# %%
dataM, timeM = DAQ_Measuring(DAQ_Settings1,1000,30,M8190A)

fig,ax= plt.subplots()
ax.grid(True)

#plt.plot(timeMs,dataMs[1]*1000,label= 'Marker Channel {chan}'.format(chan=DAQ_Settings1['Analog Channel Input Marker']),color='purple')
plt.plot(timeM,dataM*1000,label= '{b} samples'.format(b=len(dataM)),color='orange')

ax.set_ylabel('V  [mV]')
ax.set_xlabel('t  [ms]')
ax.set_title('AutoCorrelation Scheme Measured with DAC, Overlaping Step ') #Voltage Offset = 3mV, Marker Ampl = 50mV 
ax.legend(loc=0)
#plt.legend(bbox_to_anchor=(2.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
#fig.savefig('AutoCorrelation Scheme Meaasured with DAC, Overlaping Step.pdf',bbox_inches='tight')
# Out:
# Triggering Pulse Stoped
